# %%
import pandas as pd

# %%
ls data
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6C76-095F
#
#  Directory of C:\Users\Peter\Documents\GitHub\edmonton-pets\data
#
# 2022-01-03  01:20 AM    <DIR>          .
# 2022-01-03  01:20 AM    <DIR>          ..
# 2022-01-03  01:19 AM        18,713,077 Pet__Licenses_by_Neighbourhood.csv
# 2022-01-03  01:20 AM        56,106,505 Pet_License_History_by_Neighbourhood.csv
#                2 File(s)     74,819,582 bytes
#                2 Dir(s)  659,516,493,824 bytes free

# %%
path = "data/Pet_License_History_by_Neighbourhood.csv"

# %%
tpet_df = pd.read_csv(path)

# %%
tpet_df
# Out:
#                   row_id         pet_id animal_type     sex  \
# 0       D103136773000_01  D103136773000         Dog    Male
# 1       D103136773000_02  D103136773000         Dog    Male
# 2       D103136773000_03  D103136773000         Dog    Male
# 3       D103136773000_04  D103136773000         Dog    Male
# 4       D103136773000_05  D103136773000         Dog    Male
# ...                  ...            ...         ...     ...
# 619928  C167987464300_01  C167987464300         Cat  Female
# 619929  C168182827500_01  C168182827500         Cat    Male
# 619930  C170302645900_01  C170302645900         Cat  Female
# 619931  C170589666300_01  C170589666300         Cat  Female
# 619932  C171624409300_01  C171624409300         Cat  Female
#
#         spayed_or_neutered transaction_date transaction_outcome  \
# 0                     True       2013-01-22      License Issued
# 1                     True       2014-01-31      License Issued
# ...

# %%
tpet_df.dtypes
# Out:
# row_id                    object
# pet_id                    object
# animal_type               object
# sex                       object
# spayed_or_neutered          bool
# transaction_date          object
# transaction_outcome       object
# current_license_status    object
# neighbourhood_id           int64
# neighbourhood             object
# dtype: object

# %%
tpet_df.current_license_status.value_counts()
# Out:
# ISSUED    84438
# DELINQ    43212
# RENEW      2907
# NSF          45
# EXPRED        1
# ACCEPT        1
# Name: current_license_status, dtype: int64
